# %% [markdown]
# # pandas
#
# memasukan import pandas kita bisa memanipulasi, analisis, dan eksplorasi data dalam bentuk tabel. juga pd adalah singkatan dari pandas dan as itu berfungsi untuk membaca singkatannya itu.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # read
#
# read di gunakan untuk membaca sebuah data sekaligus menampilkannya dan memasukan sesuai tipe data tersebut, karena ada bermacam-macam tipe data misalnya csv, json, dll. kita tinggal memasukan dengan cara menuliskan (read_csv) atau (read_json) sesuaikan dengan tipe data kita.

# %%
df = pd.read_csv("/content/DaftarSaham.csv")

df
# Out:
#      Code                          Name          ListingDate        Shares  \
# 0    AALI       Astra Agro Lestari Tbk.           1997-12-09  1.924688e+09
# 1    ABBA             Mahaka Media Tbk.           2002-04-03  3.935893e+09
# 2    ABDA  Asuransi Bina Dana Arta Tbk.           1989-07-06  6.208067e+08
# 3    ABMM            ABM Investama Tbk.           2011-12-06  2.753165e+09
# 4    ACES   Ace Hardware Indonesia Tbk.           2007-11-06  1.715000e+10
# ..    ...                           ...                  ...           ...
# 824  ZATA       Bersama Zatta Jaya Tbk.  2022-11-10 00:00:00  8.496000e+09
# 825  ZBRA     Dosni Roha Indonesia Tbk.           1991-08-01  2.510706e+09
# 826  ZINC        Kapuas Prima Coal Tbk.           2017-10-16  2.525000e+10
# 827  ZONE            Mega Perintis Tbk.           2018-12-12  8.701715e+08
# 828  ZYRX  Zyrexindo Mandiri Buana Tbk.           2021-03-30  1.333333e+09
#
# ...

# %% [markdown]
# # Head
#
# Berfunsi untuk menampilkan dataset 5 teratas

# %%
df.head()
# Out:
#    Code                          Name ListingDate        Shares  ListingBoard  \
# 0  AALI       Astra Agro Lestari Tbk.  1997-12-09  1.924688e+09         Utama
# 1  ABBA             Mahaka Media Tbk.  2002-04-03  3.935893e+09  Pengembangan
# 2  ABDA  Asuransi Bina Dana Arta Tbk.  1989-07-06  6.208067e+08  Pengembangan
# 3  ABMM            ABM Investama Tbk.  2011-12-06  2.753165e+09         Utama
# 4  ACES   Ace Hardware Indonesia Tbk.  2007-11-06  1.715000e+10         Utama
#
#                    Sector  LastPrice     MarketCap    MinutesFirstAdded  \
# 0  Consumer Non-Cyclicals     8000.0  1.539751e+13  2021-11-01 09:00:00
# 1      Consumer Cyclicals      142.0  5.588968e+11  2021-11-01 09:00:00
# 2              Financials     6700.0  4.159405e+12  2021-11-01 09:00:00
# 3             Industrials     3050.0  8.397153e+12  2021-11-01 09:00:00
# 4      Consumer Cyclicals      490.0  8.403500e+12  2021-11-01 09:00:00
#
# ...

# %% [markdown]
# # Tail
#
# Berfunsi untuk menampilkan dataset 5 terbawah

# %%
df.tail()
# Out:
#      Code                          Name          ListingDate        Shares  \
# 824  ZATA       Bersama Zatta Jaya Tbk.  2022-11-10 00:00:00  8.496000e+09
# 825  ZBRA     Dosni Roha Indonesia Tbk.           1991-08-01  2.510706e+09
# 826  ZINC        Kapuas Prima Coal Tbk.           2017-10-16  2.525000e+10
# 827  ZONE            Mega Perintis Tbk.           2018-12-12  8.701715e+08
# 828  ZYRX  Zyrexindo Mandiri Buana Tbk.           2021-03-30  1.333333e+09
#
#      ListingBoard              Sector  LastPrice     MarketCap  \
# 824         Utama  Consumer Cyclicals      112.0  9.515520e+11
# 825  Pengembangan         Industrials      540.0  1.355781e+12
# 826  Pengembangan     Basic Materials       50.0  1.262500e+12
# 827  Pengembangan  Consumer Cyclicals     1205.0  1.048557e+12
# 828  Pengembangan          Technology      310.0  4.133333e+11
#
#        MinutesFirstAdded   MinutesLastUpdated     HourlyFirstAdded  \
# ...

# %% [markdown]
# # Describe
#
# Menampilkan statistik ringkasan seperti yang tertera di bawah

# %%
df.describe()
# Out:
#              Shares     LastPrice     MarketCap
# count  8.290000e+02    824.000000  8.240000e+02
# mean   1.094694e+10   1363.453883  1.007663e+13
# std    4.539593e+10   3733.432446  5.053142e+13
# min    3.600000e+06     25.000000  9.000000e+09
# 25%    1.230840e+09    101.750000  2.975283e+11
# 50%    3.128090e+09    287.000000  1.111305e+12
# 75%    9.327465e+09    975.000000  4.236953e+12
# max    1.184364e+12  38000.000000  1.012951e+15

# %% [markdown]
# # Shape
#
# Menghitung jumlah baris dan kolom

# %%
df.shape
# Out:
# (829, 14)

# %% [markdown]
# # Info
#
# Menampilkan ringkasan Dataset seperti jumlah kolom dan baris, dan tipedatanya

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829 entries, 0 to 828
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Code                829 non-null    object
#  1   Name                829 non-null    object
#  2   ListingDate         829 non-null    object
#  3   Shares              829 non-null    float64
#  4   ListingBoard        829 non-null    object
#  5   Sector              829 non-null    object
#  6   LastPrice           824 non-null    float64
#  7   MarketCap           824 non-null    float64
#  8   MinutesFirstAdded   787 non-null    object
#  9   MinutesLastUpdated  787 non-null    object
#  10  HourlyFirstAdded    806 non-null    object
#  11  HourlyLastUpdated   806 non-null    object
#  12  DailyFirstAdded     824 non-null    object
#  13  DailyLastUpdated    824 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 90.8+ KB

# %% [markdown]
# # Studi Kasus
#
# Analisis tren MarketCap (Kapitalisasi Pasar) saham di Bursa Efek iIndonesia berdasarkan sector.

# %%
df.groupby("Sector")["MarketCap"].sum().sort_values(ascending=False)
# Out:
# Sector
# Financials                   3.244858e+15
# Consumer Non-Cyclicals       1.154333e+15
# Infrastructures              8.037614e+14
# Basic Materials              7.283171e+14
# Energy                       6.725386e+14
# Technology                   4.009160e+14
# Industrials                  3.908291e+14
# Consumer Cyclicals           3.450494e+14
# Healthcare                   2.889857e+14
# Properties & Real Estate     2.321074e+14
# Transportation & Logistic    4.144836e+13
# Name: MarketCap, dtype: float64

# %% [markdown]
# # BUSINESS UNDERSTANDING

# %% [markdown]
# ## Background
#
# MarketCap(kapitalisasi) adalah salah satu indikator utama daloam menilai ukuran dan nilai sebuah perusahaan di pasar saham. investor dan analis menggunakan MarketCap untuk memahami sector mana yang paling dominan dan stabil. Dengan menganalisanya kita bisa mengetahui MarketCap berdasarkan sector agar tau industri mana yang memiliki pengaruh terbesar di Bursa Efek Indonesia serta melihat pola distribusinya.

# %% [markdown]
# ## Business Objective
#
# Tujuan menganalisis MarketCap saham di Bursa Efek Indonesia untuk mengendetifikasi tren,distribusi dan perbandingan antar sector. Hasil analisis ini bisa digunakan oleh para investor atau analis pasar untuk memahami bagaimana perusahaan dalam berbagai sektor berkembang berdasarkan MarketCap.

# %% [markdown]
# ## Assess Situation
#
# situasi bisnis yang mendasari sebuah analisis ini adalah pendapatan setiap sektor yang lebih stabil seperti sektor keuangan dan kebutuhan tetapi cenderung lebih mahal dan juga sektor teknologi dan energi memiliki harga yang lebih bervariasi.

# %% [markdown]
# ## Data Mining Goals
#
# Mengidentifikasi sektor dengan MarketCap terbesar di Bursa Efek Indonesia serta menganalisis distribusi MarketCap antar sector. Menghitung MarketCap per sector berdasarkan jumlah saham, Menganalisis MarketCap guna mengidentifikasi sector mana yang mendominasi.

# %% [markdown]
# ## Project Plan
#
# Bertujuan untuk memahami dinamika sektor saham di indonesia, dengan berfokus kepada MarketCap, tren harga, dan sektor yang memiliki pertumbuhan terbaik. tools yang di gunakan yaitu ada python untuk analisis data, google colab untuk dokumentasi, dan ada Github untuk penyimpanan.

# %% [markdown]
# # CHECKPOIN 2

# %%
df = pd.read_csv("/content/DaftarSaham.csv")

df
# Out:
#      Code                          Name          ListingDate        Shares  \
# 0    AALI       Astra Agro Lestari Tbk.           1997-12-09  1.924688e+09
# 1    ABBA             Mahaka Media Tbk.           2002-04-03  3.935893e+09
# 2    ABDA  Asuransi Bina Dana Arta Tbk.           1989-07-06  6.208067e+08
# 3    ABMM            ABM Investama Tbk.           2011-12-06  2.753165e+09
# 4    ACES   Ace Hardware Indonesia Tbk.           2007-11-06  1.715000e+10
# ..    ...                           ...                  ...           ...
# 824  ZATA       Bersama Zatta Jaya Tbk.  2022-11-10 00:00:00  8.496000e+09
# 825  ZBRA     Dosni Roha Indonesia Tbk.           1991-08-01  2.510706e+09
# 826  ZINC        Kapuas Prima Coal Tbk.           2017-10-16  2.525000e+10
# 827  ZONE            Mega Perintis Tbk.           2018-12-12  8.701715e+08
# 828  ZYRX  Zyrexindo Mandiri Buana Tbk.           2021-03-30  1.333333e+09
#
# ...

# %% [markdown]
# ## Lakukan pengecekan terhadap data

# %% [markdown]
# ### pengecekan data missing values

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Code                  0.000000
# Name                  0.000000
# ListingDate           0.000000
# Shares                0.000000
# ListingBoard          0.000000
# Sector                0.000000
# LastPrice             0.603136
# MarketCap             0.603136
# MinutesFirstAdded     5.066345
# MinutesLastUpdated    5.066345
# HourlyFirstAdded      2.774427
# HourlyLastUpdated     2.774427
# DailyFirstAdded       0.603136
# DailyLastUpdated      0.603136
# dtype: float64

# %%
df[df["LastPrice"].isnull()]
# Out:
#      Code                         Name ListingDate        Shares  \
# 319  HDTX  Panasia Indo Resources Tbk.  1990-06-06  3.601463e+09
# 548  NIPS                 Nipress Tbk.  1991-07-24  1.635333e+09
# 723  SUGI            Sugih Energy Tbk.  2002-06-19  2.481154e+10
# 770  TRIL    Triwira Insanlestari Tbk.  2008-01-28  1.200000e+09
# 773  TRIO           Trikomsel Oke Tbk.  2009-04-14  2.600749e+10
#
#      ListingBoard              Sector  LastPrice  MarketCap MinutesFirstAdded  \
# 319         Utama  Consumer Cyclicals        NaN        NaN               NaN
# 548  Pengembangan  Consumer Cyclicals        NaN        NaN               NaN
# 723  Pengembangan              Energy        NaN        NaN               NaN
# 770  Pengembangan         Industrials        NaN        NaN               NaN
# 773         Utama  Consumer Cyclicals        NaN        NaN               NaN
#
#     MinutesLastUpdated HourlyFirstAdded HourlyLastUpdated DailyFirstAdded  \
# ...

# %%
df[df["MarketCap"].isnull()]
# Out:
#      Code                         Name ListingDate        Shares  \
# 319  HDTX  Panasia Indo Resources Tbk.  1990-06-06  3.601463e+09
# 548  NIPS                 Nipress Tbk.  1991-07-24  1.635333e+09
# 723  SUGI            Sugih Energy Tbk.  2002-06-19  2.481154e+10
# 770  TRIL    Triwira Insanlestari Tbk.  2008-01-28  1.200000e+09
# 773  TRIO           Trikomsel Oke Tbk.  2009-04-14  2.600749e+10
#
#      ListingBoard              Sector  LastPrice  MarketCap MinutesFirstAdded  \
# 319         Utama  Consumer Cyclicals        NaN        NaN               NaN
# 548  Pengembangan  Consumer Cyclicals        NaN        NaN               NaN
# 723  Pengembangan              Energy        NaN        NaN               NaN
# 770  Pengembangan         Industrials        NaN        NaN               NaN
# 773         Utama  Consumer Cyclicals        NaN        NaN               NaN
#
#     MinutesLastUpdated HourlyFirstAdded HourlyLastUpdated DailyFirstAdded  \
# ...

# %% [markdown]
# ### pengecekan data duplikat

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Code, Name, ListingDate, Shares, ListingBoard, Sector, LastPrice, MarketCap, MinutesFirstAdded, MinutesLastUpdated, HourlyFirstAdded, HourlyLastUpdated, DailyFirstAdded, DailyLastUpdated]
# Index: []

# %% [markdown]
# ### pengecekan data outliers

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom      Persentase Outliers
# Shares               11.459590
# LastPrice            12.545235
# MarketCap            14.716526

# %% [markdown]
# ## PENANGAN DATA

# %% [markdown]
# ### penanganan data missing values

# %%
df["LastPrice"].dropna().describe()
# Out:
# count      824.000000
# mean      1363.453883
# std       3733.432446
# min         25.000000
# 25%        101.750000
# 50%        287.000000
# 75%        975.000000
# max      38000.000000
# Name: LastPrice, dtype: float64

# %% [markdown]
# Melakukan penangan data kosong pada LastPrice agar ada isinya

# %%
df["LastPrice"] = df["LastPrice"].fillna(df["LastPrice"].dropna().mean())

# %% [markdown]
# Melakukan pengecakan hasil dari missing values "lastprice" dengan menggunakan "dailyfirstadded" karena mau didrop.

# %%
df[df["DailyFirstAdded"].isnull()]
# Out:
#      Code                         Name ListingDate        Shares  \
# 319  HDTX  Panasia Indo Resources Tbk.  1990-06-06  3.601463e+09
# 548  NIPS                 Nipress Tbk.  1991-07-24  1.635333e+09
# 723  SUGI            Sugih Energy Tbk.  2002-06-19  2.481154e+10
# 770  TRIL    Triwira Insanlestari Tbk.  2008-01-28  1.200000e+09
# 773  TRIO           Trikomsel Oke Tbk.  2009-04-14  2.600749e+10
#
#      ListingBoard              Sector    LastPrice  MarketCap  \
# 319         Utama  Consumer Cyclicals  1363.453883        NaN
# 548  Pengembangan  Consumer Cyclicals  1363.453883        NaN
# 723  Pengembangan              Energy  1363.453883        NaN
# 770  Pengembangan         Industrials  1363.453883        NaN
# 773         Utama  Consumer Cyclicals  1363.453883        NaN
#
#     MinutesFirstAdded MinutesLastUpdated HourlyFirstAdded HourlyLastUpdated  \
# 319               NaN                NaN              NaN               NaN
# ...

# %% [markdown]
# Melakukan agar menambahkan nilai yang hilang di MarketCap dengan mengalikan antara Shares dan LastPrice

# %%
df["MarketCap"] = df["Shares"] * df["LastPrice"]

# %% [markdown]
# Melakukan pengecakan hasil dari missing values "MarketCap" dengan menggunakan "dailyfirstadded" karena mau didrop.

# %%
df[df["DailyFirstAdded"].isnull()]
# Out:
#      Code                         Name ListingDate        Shares  \
# 319  HDTX  Panasia Indo Resources Tbk.  1990-06-06  3.601463e+09
# 548  NIPS                 Nipress Tbk.  1991-07-24  1.635333e+09
# 723  SUGI            Sugih Energy Tbk.  2002-06-19  2.481154e+10
# 770  TRIL    Triwira Insanlestari Tbk.  2008-01-28  1.200000e+09
# 773  TRIO           Trikomsel Oke Tbk.  2009-04-14  2.600749e+10
#
#      ListingBoard              Sector    LastPrice     MarketCap  \
# 319         Utama  Consumer Cyclicals  1363.453883  4.910428e+12
# 548  Pengembangan  Consumer Cyclicals  1363.453883  2.229702e+12
# 723  Pengembangan              Energy  1363.453883  3.382939e+13
# 770  Pengembangan         Industrials  1363.453883  1.636145e+12
# 773         Utama  Consumer Cyclicals  1363.453883  3.546002e+13
#
#     MinutesFirstAdded MinutesLastUpdated HourlyFirstAdded HourlyLastUpdated  \
# 319               NaN                NaN              NaN               NaN
# ...

# %% [markdown]
# ### penanganan outliers

# %%
columns_to_impute = ["Shares", "LastPrice", "MarketCap"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom      Persentase Outliers
# Shares                     0.0
# LastPrice                  0.0
# MarketCap                  0.0

# %% [markdown]
# ### penanganan nilai yang tidak kosisten
#
# digunakan agar semua nilai bisa menjadi konsisten dan tidak berbeda-berbeda

# %%
df["ListingDate"] = pd.to_datetime(df["ListingDate"], format="mixed")

df["MinutesFirstAdded"] = pd.to_datetime(df["MinutesFirstAdded"], format="mixed")

df["MinutesLastUpdated"] = pd.to_datetime(df["MinutesLastUpdated"], format="mixed")

df["HourlyFirstAdded"] = pd.to_datetime(df["HourlyFirstAdded"], format="mixed")

df["HourlyLastUpdated"] = pd.to_datetime(df["HourlyLastUpdated"], format="mixed")

df["DailyFirstAdded"] = pd.to_datetime(df["DailyFirstAdded"], format="mixed")

df["DailyLastUpdated"] = pd.to_datetime(df["DailyLastUpdated"], format="mixed")

# %%
df
# Out:
#      Code                          Name ListingDate        Shares  \
# 0    AALI       Astra Agro Lestari Tbk.  1997-12-09  1.924688e+09
# 1    ABBA             Mahaka Media Tbk.  2002-04-03  3.935893e+09
# 2    ABDA  Asuransi Bina Dana Arta Tbk.  1989-07-06  6.208067e+08
# 3    ABMM            ABM Investama Tbk.  2011-12-06  2.753165e+09
# 4    ACES   Ace Hardware Indonesia Tbk.  2007-11-06  1.715000e+10
# ..    ...                           ...         ...           ...
# 824  ZATA       Bersama Zatta Jaya Tbk.  2022-11-10  8.496000e+09
# 825  ZBRA     Dosni Roha Indonesia Tbk.  1991-08-01  2.510706e+09
# 826  ZINC        Kapuas Prima Coal Tbk.  2017-10-16  2.147240e+10
# 827  ZONE            Mega Perintis Tbk.  2018-12-12  8.701715e+08
# 828  ZYRX  Zyrexindo Mandiri Buana Tbk.  2021-03-30  1.333333e+09
#
#      ListingBoard                  Sector  LastPrice     MarketCap  \
# 0           Utama  Consumer Non-Cyclicals     2322.0  1.032592e+13
# ...

# %% [markdown]
# ### Data Redaction
#
# Melakukan reduksi data (Data Reduction) dengan menghapus kolom-kolom yang tidak relevan dengan studi kasus saya.

# %%
df = df.drop("DailyLastUpdated", axis=1)

# %%
df = df.drop("DailyFirstAdded", axis=1)

# %%
df = df.drop("HourlyLastUpdated", axis=1)

# %%
df = df.drop("HourlyFirstAdded", axis=1)

# %%
df = df.drop("MinutesLastUpdated", axis=1)

# %%
df = df.drop("MinutesFirstAdded", axis=1)

# %%
df
# Out:
#      Code                          Name ListingDate        Shares  \
# 0    AALI       Astra Agro Lestari Tbk.  1997-12-09  1.924688e+09
# 1    ABBA             Mahaka Media Tbk.  2002-04-03  3.935893e+09
# 2    ABDA  Asuransi Bina Dana Arta Tbk.  1989-07-06  6.208067e+08
# 3    ABMM            ABM Investama Tbk.  2011-12-06  2.753165e+09
# 4    ACES   Ace Hardware Indonesia Tbk.  2007-11-06  1.715000e+10
# ..    ...                           ...         ...           ...
# 824  ZATA       Bersama Zatta Jaya Tbk.  2022-11-10  8.496000e+09
# 825  ZBRA     Dosni Roha Indonesia Tbk.  1991-08-01  2.510706e+09
# 826  ZINC        Kapuas Prima Coal Tbk.  2017-10-16  2.147240e+10
# 827  ZONE            Mega Perintis Tbk.  2018-12-12  8.701715e+08
# 828  ZYRX  Zyrexindo Mandiri Buana Tbk.  2021-03-30  1.333333e+09
#
#      ListingBoard                  Sector  LastPrice     MarketCap
# 0           Utama  Consumer Non-Cyclicals     2322.0  1.032592e+13
# ...

# %% [markdown]
# ### hasil studi kasus
#
# Analisis tren MarketCap (Kapitalisasi Pasar) saham di Bursa Efek iIndonesia berdasarkan sector pada check poin 2.

# %%
df.groupby("Sector")["MarketCap"].sum().sort_values(ascending=False)
# Out:
# Sector
# Financials                   4.846420e+14
# Consumer Non-Cyclicals       4.003262e+14
# Consumer Cyclicals           2.855728e+14
# Basic Materials              2.694865e+14
# Energy                       2.629991e+14
# Infrastructures              2.066211e+14
# Properties & Real Estate     1.756799e+14
# Healthcare                   1.344076e+14
# Technology                   1.089940e+14
# Industrials                  9.297189e+13
# Transportation & Logistic    4.019282e+13
# Name: MarketCap, dtype: float64

# %% [markdown]
# # CHECKPOIN 3

# %% [markdown]
# ## Barchart dengan gruopby
#
# Ini digunakan agar melihat visualisai Kapitalisasi Pasar dengan diagram batang persektornya dengan mengukur dari nilai pertamanya saja.

# %%
plt.figure(figsize=(12, 5))
df.groupby('Sector')['MarketCap'].sum().plot(kind='bar', color='red')
plt.title('Jumlah Kapitalisasi Pasar Berdasarkan Sektor')
plt.xlabel('Sektor')
plt.ylabel('Jumlah Kapitalisasi Pasar(Dalam Miliar)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Barplot
#
#  Barplot digunakan untuk menghitung dan menampilkan rata-rata Kapitalisasi Pasr (MarketCap) persektor dengan mengukur dari nilai pertama dan ditambah garis untuk menentukan rata-ratanya.

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Sector', y='MarketCap',hue="Sector", data=df, palette='viridis')
plt.title('Kapitalisasi Pasar Berdasarkan Sektor')
plt.xlabel('Sektor')
plt.ylabel('Kapitalisasi Pasar (dalam miliar)')
plt.xticks(rotation=45)
plt.show()
